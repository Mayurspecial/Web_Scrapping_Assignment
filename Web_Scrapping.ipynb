# %%
# !pip install bs4
# !pip install requests

# %%
from bs4 import BeautifulSoup
import requests
import re
from glob import glob
import pandas as pd
from datetime import datetime
from time import sleep

# %% [markdown]
# <b> 1.Write a python program to display all the header tags from ‘en.wikipedia.org/wiki/Main_Page’.</b>

# %%
page=requests.get("https://en.wikipedia.org/wiki/Main_Page")
page
# Out:
# <Response [200]>

# %%
soup5 = BeautifulSoup(page.content)
soup5
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Wikipedia, the free encyclopedia</title>
# ...

# %%
titles = soup5.find_all(['h1','h2','h3','h4','h5','h6'])
print("List of all Header Tags :")
for heading in soup5.find_all(["h1", "h2", "h3"]):
    print(heading.name + ' ' + heading.text.strip())
#titles
# Out:
# List of all Header Tags :
# h1 Main Page
# h2 From today's featured article
# h2 Did you know ...
# h2 In the news
# h2 On this day
# h2 From today's featured list
# h2 Today's featured picture
# h2 Other areas of Wikipedia
# h2 Wikipedia's sister projects
# h2 Wikipedia languages
# h2 Navigation menu
# h3 Personal tools
# h3 Namespaces
# h3 Variants
# h3 Views
# h3 More
# h3 Search
# h3 Navigation
# h3 Contribute
# h3 Tools
# h3 Print/export
# h3 In other projects
# h3 Languages

# %% [markdown]
# <b>2. Write a python program to display IMDB’s Top rated 100 movies’ data (i.e. Name, IMDB rating, Year of release) and make data frame.</b>

# %%
movie=requests.get("https://www.imdb.com/chart/top/")
movie
# Out:
# <Response [200]>

# %%
soup1 = BeautifulSoup(movie.content)
soup1
# Out:
# <!DOCTYPE html>
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="app-id=342792525, app-argument=imdb:///?src=mdot" name="apple-itunes-app"/>
# <style>
#                 body#styleguide-v2 {
#                     background: no-repeat fixed center top #000;
#                 }
#             </style>
# <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:'java'};</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("bb", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <title>IMDb Top 250 - IMDb</title>
# <script>(function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <script>
#     if (typeof uet == 'function') {
# ...

# %%
movies = soup1.select('td.titleColumn')
ratings = [b.attrs.get('data-value') for b in soup1.select('td.posterColumn span[name=ir]')]
imdb = []

# Store each item into dictionary (data), then put those into a list (imdb)
for index in range(0, len(movies)):
    # Seperate movie into: 'title', 'year'
    movie_string = movies[index].get_text()
    movie = (' '.join(movie_string.split()).replace('.', ''))
    movie_title = movie[len(str(index))+1:-3]
    year = re.search('\((.*?)\)', movie_string).group(1)
    place = movie[:len(str(index))-(len(movie))]
    data = {"movie_title": movie_title[0:100],
            "year": year[0:100],
            "rating": ratings[index],
            }
    imdb.append(data)

for item in imdb:
    print(item['movie_title'], '('+item['year']+') -', 'IMDB rating:', item['rating'])
# Out:
# The Shawshank Redemption (19 (1994) - IMDB rating: 9.219814765390494
# The Godfather (19 (1972) - IMDB rating: 9.14754660107155
# The Godfather: Part II (19 (1974) - IMDB rating: 8.97998849232208
# The Dark Knight (20 (2008) - IMDB rating: 8.97003151465443
# 12 Angry Men (19 (1957) - IMDB rating: 8.93515688024201
# Schindler's List (19 (1993) - IMDB rating: 8.909521090751403
# The Lord of the Rings: The Return of the King (20 (2003) - IMDB rating: 8.885387551972666
# Pulp Fiction (19 (1994) - IMDB rating: 8.838376723475905
# Il buono, il brutto, il cattivo (19 (1966) - IMDB rating: 8.78778610499141
#  The Lord of the Rings: The Fellowship of the Ring (20 (2001) - IMDB rating: 8.77667679778925
# Fight Club (19 (1999) - IMDB rating: 8.7540816657397
# Forrest Gump (19 (1994) - IMDB rating: 8.743217151560078
# Inception (20 (2010) - IMDB rating: 8.7143735614129
# The Lord of the Rings: The Two Towers (20 (2002) - IMDB rating: 8.699509936652186
# ...

# %% [markdown]
# <b> 3.Write a python program to display IMDB’s Top rated 100 Indian movies’ data (i.e. Name, IMDB rating, Year of release) and make data frame.</b>

# %%
imovie=requests.get("https://www.imdb.com/india/top-rated-indian-movies/")
imovie
# Out:
# <Response [200]>

# %%
soup2 = BeautifulSoup(imovie.content)
soup2
# Out:
# <!DOCTYPE html>
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="app-id=342792525, app-argument=imdb:///?src=mdot" name="apple-itunes-app"/>
# <style>
#                 body#styleguide-v2 {
#                     background: no-repeat fixed center top #000;
#                 }
#             </style>
# <style>
#             body#styleguide-v2 #root {
#                 box-shadow: none;
#             }
#         </style>
# <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:'java'};</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("bb", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <title>Top Rated Indian Movies - IMDb</title>
# ...

# %%
imovies = soup2.select('td.titleColumn')
ratings = [b.attrs.get('data-value') for b in soup2.select('td.posterColumn span[name=ir]')]
imdb = []

# Store each item into dictionary (data), then put those into a list (imdb)
for index in range(0, len(imovies)):
    # Seperate movie into: 'title', 'year'
    imovie_string = imovies[index].get_text()
    imovie = (' '.join(imovie_string.split()).replace('.', ''))
    imovie_title = imovie[len(str(index))+1:-3]
    year = re.search('\((.*?)\)', imovie_string).group(1)
    place = imovie[:len(str(index))-(len(imovie))]
    data = {"movie_title": imovie_title[0:100],
            "year": year[0:100],
            "rating": ratings[index],
            }
    imdb.append(data)

for item in imdb:
    print(item['movie_title'], '('+item['year']+') -', 'IMDB rating:', item['rating'])
# Out:
# Pather Panchali (19 (1955) - IMDB rating: 8.505762579637882
# Nayakan (19 (1987) - IMDB rating: 8.48161122430972
# Pariyerum Perumal (20 (2018) - IMDB rating: 8.47493177714247
# Anbe Sivam (20 (2003) - IMDB rating: 8.471845391493543
# Golmaal (19 (1979) - IMDB rating: 8.462942433131385
# Apur Sansar (19 (1959) - IMDB rating: 8.460350857471859
# C/o Kancharapalem (20 (2018) - IMDB rating: 8.45962585265485
# Manichitrathazhu (19 (1993) - IMDB rating: 8.436720113321291
# Kireedam (19 (1989) - IMDB rating: 8.436671085321073
#  Natsamrat (20 (2016) - IMDB rating: 8.43475159568866
# Drishyam 2 (20 (2021) - IMDB rating: 8.426387615917351
# 96 (20 (2018) - IMDB rating: 8.41819824788283
# Black Friday (20 (2004) - IMDB rating: 8.408950697799558
# Thevar Magan (19 (1992) - IMDB rating: 8.406025894877251
# Kumbalangi Nights (20 (2019) - IMDB rating: 8.38951021035897
# 3 Idiots (20 (2009) - IMDB rating: 8.348565742334399
# Visaaranai (20 (2015) - IMDB rating: 8.345380245963646
# ...

# %% [markdown]
# <b>4. Write a python program to scrap book name, author name, genre and book review of any 5 books from‘www.bookpage.com’</b>

# %%
book=requests.get("https://www.bookpage.com")
book
# Out:
# <Response [200]>

# %%
soup3 = BeautifulSoup(book.content)
soup3
# Out:
# <!DOCTYPE html>
# <html lang="en" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/">
# <head>
# <title>BookPage | Discover your next great book!</title>
# <meta content="Find expert book recommendations for the best books to read in all genres." name="description"/>
# <meta content="books and literature, writing and writers" name="keywords"/>
# <link href="https://bookpage.com/" rel="canonical"/>
# <meta content="BookPage.com" property="og:site_name"/>
# <meta content="Discover your next great book!" property="og:title"/>
# <meta content="Find expert book recommendations for the best books to read in all genres." property="og:description"/>
# <meta content="website" property="og:type"/>
# <meta content="https://bookpage.com/" property="og:url"/>
# <meta content="//www.bookpage.com/default_image.jpg" property="og:image"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="@bookpage" name="twitter:site"/>
# ...

# %%
bn = soup3.find_all("h4", class_="italic")
Book_Name = []
for i in bn:
    for j in i.find_all("a"):
            Book_Name.append(i.text.strip("\n"))
            
    an = soup3.find_all("p", class_='sans bold')
    Author = []
    for i in an:
        Author.append(i.text.strip("\n"))
    
    rn = soup3.find_all("p", class_='excerpt')
    Review = []
    for i in rn:
        Review.append(i.text.strip("\n"))
        
    Book_Reviews = pd.DataFrame()
    Book_Reviews['Book_Name'] = Book_Name[0:5]
    Book_Reviews['Author_Name'] = Author[0]
    Book_Reviews['Review'] = Review[0]
    
  #  print("Shape of Book Review is {} rows and {} columns.".format(*Book_Reviews.shape))
    print(Book_Reviews.head(2))
# Out:
#                            Book_Name                          Author_Name  \
# 0  From book to film, and back again  Behind the Book by Robert J. Harris
#
#                                               Review
# 0  How a classic film series and a legendary kill...
#                            Book_Name                          Author_Name  \
# 0  From book to film, and back again  Behind the Book by Robert J. Harris
# 1              Book Clubs: June 2021  Behind the Book by Robert J. Harris
#
#                                               Review
# 0  How a classic film series and a legendary kill...
# 1  How a classic film series and a legendary kill...
#                            Book_Name                          Author_Name  \
# 0  From book to film, and back again  Behind the Book by Robert J. Harris
# 1              Book Clubs: June 2021  Behind the Book by Robert J. Harris
#
#                                               Review
# ...

# %% [markdown]
# <b>5.Write a python program to scrape cricket rankings from ‘www.icc-cricket.com’</b>

# %%
cric=requests.get("https://www.icc-cricket.com")
cric
# Out:
# <Response [200]>

# %%
s5 = BeautifulSoup(cric.content)

# %% [markdown]
# <b> i.Top 10 ODI teams in men’s cricket along with the records for matches, points and rating.</b>

# %%
    t1 = s5.find_all('span', class_='u-hide-phablet')
    Team_Name = []
    for i in t1:
        Team_Name.append(i.text)
        
    m1 = s5.find_all('td', class_='rankings-block__banner--matches')
    Matches = []
    for i in m1:
        Matches.append(i.text)
        
    p1 = s5.find_all('td', class_='rankings-block__banner--points')
    Point = []
    for i in p1:
        Point.append(i.text) 
    
    r1 = s5.find_all('td', class_='rankings-block__banner--rating u-text-right')
    Rating = []
    for i in r1:
        Rating.append(i.text.strip('\n'))
    Ratings = [] 
    Ratings.append(Rating[0].strip())
    
    m1 = s5.find_all('td', class_='table-body__cell u-center-text')
    k = []
    for i in range(0,len(m1),2):
        k.append(m1[i])
    for i in k:
        Matches.append(i.get_text())
        
    k = []
    for i in range(1,len(m1),2):
        k.append(m1[i])
    for i in k:
        Point.append(i.get_text())
        
    r1 = s5.find_all('td', class_='table-body__cell u-text-right rating')
    for i in r1:
        Ratings.append(i.get_text().strip('\n'))
        
    ODI_Men = pd.DataFrame()
    ODI_Men['Team_Name'] = Team_Name[0:10]
    ODI_Men['Matches'] = Matches[0:10]
    ODI_Men['Ratings'] = Ratings[0:10]
    ODI_Men['Point'] = Point[0:10]
    print("Shape of dataset is {} rows and {} columns".format(*ODI_Men.shape))
    print(ODI_Men.head(3))
# Out:
# [<span class="icn icn-facebook-circle u-hide-phablet"></span>,
#  <span class="icn icn-twitter-circle u-hide-phablet"></span>,
#  <span class="icn icn-instagram-circle u-hide-phablet"></span>,
#  <span class="icn icn-youtube-circle u-hide-phablet"></span>,
#  <span class="icn icn-tiktok-circle u-hide-phablet"></span>]

# %% [markdown]
# <b>  ii. Top 10 ODI Batsmen in men along with the records of their team and rating. </b>

# %%
    p1 = s5.find_all('div', class_='rankings-block__banner--name-large')
    Player = []
    for i in p1:
        Player.append(i.text)
    
    p2 = s5.find_all('td', class_='table-body__cell rankings-table__name name')
    for i in p2:
        for j in i.find_all("a"):
            Player.append(j.text)
            
    t1 = s5.find("div", class_="rankings-block__banner--nationality")
    Team = []
    Team.append(t1.text.strip())
    
    t2 = s5.find_all("span", class_='table-body__logo-text')
    for i in t2:
        Team.append(i.text)
        
    r1 = s5.find_all('td', class_='table-body__cell rating')
    Rating = []
    for i in r1:
        Rating.append(i.text)
        
    ODI_Batsman = pd.DataFrame()
    ODI_Batsman['Team'] = Team[0:10]
    ODI_Batsman['Player'] = Player[0:10]
    ODI_Batsman['Rating'] = Rating[0:10]
    print("Shape of dataset is {} rows and {} columns".format(*ODI_Batsman.shape))
    print(ODI_Batsman.head(3))

# %% [markdown]
# <b>      iii. Top 10 ODI bowlers along with the records of their team and rating.</b>

# %%
    p1 = s5.find_all('div', class_='rankings-block__banner--name-large')
    Player = []
    for i in p1:
        Player.append(i.text)
    
    p2 = s5.find_all('td', class_='table-body__cell rankings-table__name name')
    for i in p2:
        for j in i.find_all("a"):
            Player.append(j.text)
            
    t1 = s5.find("div", class_="rankings-block__banner--nationality")
    Team = []
    Team.append(t1.text.strip())
    
    t2 = s5.find_all("span", class_='table-body__logo-text')
    for i in t2:
        Team.append(i.text)
        
    r1 = s5.find_all('td', class_='table-body__cell rating')
    Rating = []
    for i in r1:
        Rating.append(i.text)
        
    ODI_Bowler = pd.DataFrame()
    ODI_Bowler['Team'] = Team[0:10]
    ODI_Bowler['Player'] = Player[0:10]
    ODI_Bowler['Rating'] = Rating[0:10]
    print("Shape of dataset is {} rows and {} columns".format(*ODI_Bowler.shape))
    print(ODI_Bowler.head(3))

# %% [markdown]
# <b>7.Write a python program to scrape details of all the mobile phones under Rs. 20,000 listed on Amazon.in. The scraped data should include Product Name, Price, Image URL and Average Rating.</b>

# %%
prod=requests.get("https://www.amazon.in/s?i=electronics&bbn=1389401031&rh=n%3A1389401031%2Cp_36%3A500000-2000000&dc&qid=1622834808&rnid=1318502031&ref=sr_nr_p_36_1")
prod
# Out:
# <Response [503]>

# %%
so6 = BeautifulSoup(prod.content)

# %%
    name = so6.find_all('span', class_='a-size-medium a-color-base a-text-normal')
    price = so6.find_all('span', class_='a-price-whole')
    rating = so6.find_all('span', class_="a-icon-alt")
    img = so6.find_all('img', class_="s-image")
    Mobile = []
    for i in name:
        Mobile.append(i.get_text())
    Price = []
    for i in price:
        Price.append(i.get_text())
        
    Rating = []
    for i in rating:
        Rating.append(i.get_text())
        
    Image = []
    for i in img:
        Image.append(i.get('srcset'))   
        
    mdata = pd.DataFrame()
    mdata['Mobile_Name'] = Mobile[0:16]
    mdata['Mobile_Price'] = Price[0:16]
    mdata['Mobile_rating'] = Rating[0:16]
    mdata['Image_Link'] = Image[0:16]
    print("Shape of dataset is {} rows and {} columns".format(*mdata.shape))
    print(mdata.head())
# Out:
# Shape of dataset is 0 rows and 4 columns
# Empty DataFrame
# Columns: [Mobile_Name, Mobile_Price, Mobile_rating, Image_Link]
# Index: []

# %% [markdown]
# <b>8.Write a python program to extract information about the local weather from the National Weather Service
# website of USA, https://www.weather.gov/ for the city, San Francisco. You need to extract data about 7 day extended forecast display for the city. The data should include period, short description, temperature and description</b>

# %%
title=requests.get("https://forecast.weather.gov/MapClick.php?lat=37.77493000000004&lon=-122.41941999999995#.YLiGtLczbIU")
title
# Out:
# <Response [200]>

# %%
so8=BeautifulSoup(title.content)
seven_day = so8.find(id="seven-day-forecast")
forecast_items = seven_day.find_all(class_="tombstone-container")
tonight = forecast_items[0]
#print(tonight.prettify())

# %%
period = tonight.find(class_="period-name").get_text()
short_desc = tonight.find(class_="short-desc").get_text()
temp = tonight.find(class_="temp temp-high").get_text()

# %%
period_tags = seven_day.select(".tombstone-container .period-name")
periods = [pt.get_text() for pt in period_tags]
short_descs = [sd.get_text() for sd in seven_day.select(".tombstone-container .short-desc")]
temps = [t.get_text() for t in seven_day.select(".tombstone-container .temp")]
descs = [d["title"] for d in seven_day.select(".tombstone-container img")]

# %%
weather = pd.DataFrame({
    "Period": periods,
    "Short_desc": short_descs,
    "Temp": temps,
    "Desc":descs
})
weather
# Out:
#           Period                              Short_desc          Temp  \
# 0  ThisAfternoon                         Sunny andBreezy  High: 65 °F⇓
# 1        Tonight  Mostly Clearand Breezythen MostlyClear    Low: 53 °F
# 2       Saturday                                   Sunny   High: 68 °F
# 3  SaturdayNight                            Mostly Clear    Low: 52 °F
# 4         Sunday                                   Sunny   High: 68 °F
# 5    SundayNight                            Mostly Clear    Low: 52 °F
# 6         Monday                                   Sunny   High: 64 °F
# 7    MondayNight                           Partly Cloudy    Low: 51 °F
# 8        Tuesday                                   Sunny   High: 63 °F
#
#                                                 Desc
# 0  This Afternoon: Sunny, with a temperature fall...
# 1  Tonight: Mostly clear, with a low around 53. B...
# 2  Saturday: Sunny, with a high near 68. Light so...
# ...

# %% [markdown]
# <b>9 .Write a python program to scrape fresher job listings from ‘https://internshala.com/’. It should include job title,
# company name, CTC, and apply date.</b>

# %%
job=requests.get("https://internshala.com/fresher-jobs")
job
# Out:
# <Response [200]>

# %%
so9=BeautifulSoup(job.content)
title = []
company = []
ctc = []
apply_date = []
    
temp = []
    
get_titles = so9.find_all('div',class_ = "heading_4_5 profile")   
get_companies = so9.find_all('a', class_ = 'link_display_like_text')
get_ctcadate = so9.find_all('div',class_ = "item_body", id = False)
    
for cdate in get_ctcadate:
        temp.append(cdate.text.strip())
        
for t, c in zip(get_titles, get_companies):
        title.append(t.text.strip())
        company.append(c.text.strip())
    
for i in temp:
        ctc.append(i) if 'LPA' in i else apply_date.append(i)
            
Internshala = pd.DataFrame({'Title': title,
                     'Company': company,
                     'CTC': ctc,
                     'Apply Date': apply_date
                     })
print("Shape of dataset is {} rows and {} columns".format(*Internshala.shape))
print(Internshala.head())
# Out:
# Shape of dataset is 40 rows and 4 columns
#                                Title                        Company  \
# 0            PHP & LARAVEL DEVELOPER                     Nyx Wolves
# 1  Backend Developer (Ruby On Rails)  Wollfish Labs Private Limited
# 2        Customer Service Specialist                       Wono Inc
# 3                   Graphic Designer                       Wono Inc
# 4       Digital Marketing Specialist                       Wono Inc
#
#              CTC Apply Date
# 0   3 - 3.05 LPA  4 Jul' 21
# 1      6 - 8 LPA  4 Jul' 21
# 2  5.2 - 6.4 LPA  3 Jul' 21
# 3    5 - 6.5 LPA  3 Jul' 21
# 4    5 - 6.5 LPA  3 Jul' 21
